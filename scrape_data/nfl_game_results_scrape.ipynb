# %%
import pandas as pd
import numpy as np

# %%
results_df = pd.read_excel('../nfl_game_results.xlsx')

# %%
results_df.head()
# Out:
#    Week  Day       Date    Time            Winner/tie Unnamed: 5  \
# 0     1  Thu 2019-09-07  8:37PM   Pittsburgh Steelers        NaN
# 1     1  Sun 2019-09-10  1:00PM    Cincinnati Bengals          @
# 2     1  Sun 2019-09-10  1:01PM      Baltimore Ravens          @
# 3     1  Sun 2019-09-10  1:02PM  New England Patriots        NaN
# 4     1  Sun 2019-09-10  1:02PM   Philadelphia Eagles          @
#
#               Loser/tie  PtsW  PtsL  YdsW  TOW  YdsL  TOL  Season  \
# 0        Miami Dolphins    28    17   342    1   278    2    2006
# 1    Kansas City Chiefs    23    10   236    1   289    3    2006
# 2  Tampa Bay Buccaneers    27     0   271    0   142    3    2006
# 3         Buffalo Bills    19    17   319    2   240    0    2006
# 4        Houston Texans    24    10   441    1   241    0    2006
#
#               Home Team            Away Team
# 0   Pittsburgh Steelers       Miami Dolphins
# 1    Kansas City Chiefs   Cincinnati Bengals
# ...
